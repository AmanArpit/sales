# %%
import pandas as pd

# Load the CSV file using pandas
data=pd.read_csv(r"C:\Users\91700\OneDrive\Desktop\vgsales.csv")
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
df.drop('Name', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

le=preprocessing.LabelEncoder()

df['Platform'] = le.fit_transform(df['Platform'])
df['Genre'] = le.fit_transform(df['Genre'])
df['Publisher'] = le.fit_transform(df['Publisher'])

unique_platforms = df['Platform'].unique()
unique_genres = df['Genre'].unique()
unique_publishers = df['Publisher'].unique()

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a scaler object
scaler = MinMaxScaler()

# Apply normalization to all columns
df_normalized = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Check the updated statistics
print(df_normalized.describe())
# Out:
#                Rank      Platform          Year         Genre     Publisher  \
# count  16598.000000  16598.000000  16327.000000  16598.000000  16598.000000
# mean       0.500006      0.526600      0.660161      0.448011      0.509693
# std        0.288683      0.279743      0.145725      0.342001      0.308110
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.250030      0.233333      0.575000      0.090909      0.237024
# 50%        0.500000      0.533333      0.675000      0.454545      0.558824
# 75%        0.749970      0.700000      0.750000      0.727273      0.797578
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            NA_Sales      EU_Sales      JP_Sales   Other_Sales  Global_Sales
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean       0.006379      0.005053      0.007611      0.004547      0.006375
# std        0.019684      0.017414      0.030263      0.017842      0.018796
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000604
# 50%        0.001928      0.000689      0.000000      0.000946      0.001934
# 75%        0.005785      0.003790      0.003914      0.003784      0.005560
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# ## EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# if we wanted the counts instead, we could just use Count. Count returns the number of instances,
# not the sums of the values like above
x = df.groupby(['Year']).count()
x = x['Global_Sales']
y = x.index.astype(int)

plt.figure(figsize=(12,8))
colors = sns.color_palette("muted")
ax = sns.barplot(y = y, x = x, orient='h', palette=colors)
ax.set_xlabel(xlabel='Number of releases', fontsize=16)
ax.set_ylabel(ylabel='Year', fontsize=16)
ax.set_title(label='Game Releases Per Year', fontsize=20)

plt.show()

# %%
# let's choose a cutoff and drop any publishers that have published less than X games
import seaborn as sns
for i in df['Publisher'].unique():
    if df['Publisher'][df['Publisher'] == i].count() < 60:
        df['Publisher'][df['Publisher'] == i] = 'Other'

for i in df['Platform'].unique():
    if df['Platform'][df['Platform'] == i].count() < 100:
        df['Platform'][df['Platform'] == i] = 'Other'

#try plotting the new publisher and platform data
sns.countplot(x='Publisher', data=df)
plt.title("# Games Published By Publisher")
plt.xticks(rotation=-90)
plt.show()

plat_data = df['Platform'].value_counts(sort=False)
sns.countplot(y='Platform', data=df)
plt.title("# Games Published Per Console")
plt.xticks(rotation=-90)
plt.show()
# Out:
# C:\Users\91700\AppData\Local\Temp\ipykernel_22636\540890533.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Publisher'][df['Publisher'] == i] = 'Other'
# C:\Users\91700\AppData\Local\Temp\ipykernel_22636\540890533.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Platform'][df['Platform'] == i] = 'Other'

# %%
sns.barplot(x='Genre', y='Global_Sales', data=df)
plt.title("Total Sales Per Genre")
plt.xticks(rotation=-45)
plt.show()

# %% [markdown]
# ### 1. Which year of release had the highest sales worldwide?

# %%
data_year = df.groupby(by=['Year'])['Global_Sales'].sum()
data_year = data_year.reset_index()
plt.figure(figsize=(15, 10))
sns.barplot(x="Year", y="Global_Sales", data=data_year)
plt.xticks(rotation=90)
plt.title('The Highest Global Sales by Year')
plt.show()

# %% [markdown]
# Peak sales occurred around 2008-2009 with more than 600 million global sales.

# %% [markdown]
# ### 2. Which year had the most game release?

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x="Year", data=data, order = data.groupby(by=['Year'])['Name'].count().sort_values(ascending=False).index)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Therefore, in 2008-2009 sales were very high, which was more than 600 million.
# Because it is directly proportional to the number of games released in the same year, which is more than 1400 games.

# %% [markdown]
# ### 3. Which genre game have the highest sale price globally?

# %%
data_genre = df.groupby(by=['Genre'])['Global_Sales'].sum()
data_genre = data_genre.reset_index()
data_genre = data_genre.sort_values(by=['Global_Sales'], ascending=False)
plt.figure(figsize=(15, 10))
sns.barplot(x="Genre", y="Global_Sales", data=data_genre)
plt.xticks(rotation=90)
plt.title('The Highest Global Sales by Genre')
plt.show()

# %% [markdown]
# Action and Sport are the genres with the most global sales.

# %% [markdown]
# ### 4. Which genre game has been released the most in a single year?

# %%
year_max_df = df.groupby(['Year', 'Genre']).size().reset_index(name='count')
year_max_idx = year_max_df.groupby(['Year'])['count'].transform(max) == year_max_df['count']
year_max_genre = year_max_df[year_max_idx].reset_index(drop=True)
year_max_genre = year_max_genre.drop_duplicates(subset=["Year", "count"], keep='last').reset_index(drop=True)
genre = year_max_genre['Genre'].values

# %%
plt.figure(figsize=(30, 15))
g = sns.barplot(x='Year', y='count', data=year_max_genre)
index = 0
for value in year_max_genre['count'].values:
    g.text(index, value + 5, str(genre[index]) + ': ' + str(value), color='#000', size=14, rotation=90, ha="center")
    index += 1
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Action and sports are the genres that dominate game releases every year, even consecutively from 1994 to 2016.

# %% [markdown]
# ### 5. Which genre game has sold the most by year of release?

# %%
year_sale_dx = df.groupby(by=['Year', 'Genre'])['Global_Sales'].sum().reset_index()
year_sale = year_sale_dx.groupby(by=['Year'])['Global_Sales'].transform(max) == year_sale_dx['Global_Sales']
year_sale_max = year_sale_dx[year_sale].reset_index(drop=True)
genre = year_sale_max['Genre']

# %%
year_sale_dx.head()
# Out:
#      Year  Genre  Global_Sales
# 0  1980.0      0          0.34
# 1  1980.0      2          0.77
# 2  1980.0      3          2.71
# 3  1980.0      8          7.07
# 4  1980.0     10          0.49

# %%
plt.figure(figsize=(30, 18))
g = sns.barplot(x='Year', y='Global_Sales', data=year_sale_max)
index = 0
for value in year_sale_max['Global_Sales']:
    g.text(index, value + 1, str(genre[index]) + ': ' + str(round(value, 2)), color='#000', size=20, rotation=90, ha="center")
    index += 1

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As the games with the most releases every year, of course it will also affect sales.

# %% [markdown]
# ### 6. How do sales compare in each region by genre?

# %%
comp_genre = data[['Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
comp_map = comp_genre.groupby(by=['Genre']).sum()
     

comp_table = comp_map.reset_index()
comp_table = pd.melt(comp_table, id_vars=['Genre'], value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], var_name='Sale_Area', value_name='Sale_Price')
     

plt.figure(figsize=(15, 10))
sns.barplot(x='Genre', y='Sale_Price', hue='Sale_Area', data=comp_table)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Sale_Price'>

# %% [markdown]
# Action, Sports and Shooter have much sales compare with others.
# North America (NA_sales) have heights sales all the time.
# Except for Japan with a very high interest in the role-playing genre, surpassing even other regions for this genre.

# %% [markdown]
# ### 7. Which platfrom have the highest sale price globally?

# %%
data_platform = df.groupby(by=['Platform'])['Global_Sales'].sum()
data_platform = data_platform.reset_index()
data_platform = data_platform.sort_values(by=['Global_Sales'], ascending=False)
plt.figure(figsize=(15, 10))
sns.barplot(x="Platform", y="Global_Sales", data=data_platform)
plt.xticks(rotation=90)
plt.title('The Highest Global Sales by Platform')
plt.show()

# %% [markdown]
# It's clearly shown that X360, Wii, DS, and all PS are market leader.

# %% [markdown]
# ### 8. How do sales compare in each region by platform?

# %%
comp_platform = data[['Platform', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
comp_platform = comp_platform.groupby(by=['Platform']).sum().reset_index()
comp_table = pd.melt(comp_platform, id_vars=['Platform'], value_vars=['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], var_name='Sale_Area', value_name='Sale_Price')
     

plt.figure(figsize=(30, 15))
sns.barplot(x='Platform', y='Sale_Price', hue='Sale_Area', data=comp_table)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# North America and Europe are dominated by market leader platforms.

# %% [markdown]
# ### 10. Top publisher with most released games.

# %%
top_publisher = df.groupby(by=['Publisher'])['Year'].count().sort_values(ascending=False).head(20)
top_publisher = pd.DataFrame(top_publisher).reset_index()
     

plt.figure(figsize=(15, 10))
sns.countplot(x="Publisher", data=data, order = data.groupby(by=['Publisher'])['Year'].count().sort_values(ascending=False).iloc[:20].index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Electronic Arts is the publisher with the most number of games released.

# %% [markdown]
# ### 11. Which publisher have the highest sale price globally?

# %%
sale_pbl = data[['Publisher', 'Global_Sales']]
sale_pbl = sale_pbl.groupby('Publisher')['Global_Sales'].sum().sort_values(ascending=False).head(20)
sale_pbl = pd.DataFrame(sale_pbl).reset_index()
     

plt.figure(figsize=(15, 10))
sns.barplot(x='Publisher', y='Global_Sales', data=sale_pbl)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Surprisingly, even though Nintendo only has half the number of games compared to Electronic Arts, Nintendo is the publisher that gets the most sales.

# %% [markdown]
# ### 12. How much the total revenue by region?

# %%
top_sale_reg = data[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]
top_sale_reg = top_sale_reg.sum().reset_index()
top_sale_reg = top_sale_reg.rename(columns={"index": "region", 0: "sale"})
top_sale_reg
# Out:
#         region     sale
# 0     NA_Sales  4392.95
# 1     EU_Sales  2434.13
# 2     JP_Sales  1291.02
# 3  Other_Sales   797.75

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='region', y='sale', data = top_sale_reg)
# Out:
# <AxesSubplot:xlabel='region', ylabel='sale'>

# %%
labels = top_sale_reg['region']
sizes = top_sale_reg['sale']
     

plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, )
plt.show()

# %% [markdown]
# North America almost covers 50% of sales, this shows that video games in North America are more popular than in other regions.

# %%
def donut_chart(column, palette="Set2"):
    values = column.value_counts().values
    labels = column.value_counts().index
    plt.pie(values, colors=sns.color_palette(palette), 
            labels=labels, autopct="%1.1f%%", 
            startangle=90, pctdistance=0.85)
    #draw circle
    centre_circle = plt.Circle((0,0), 0.70, fc="white")
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
     

donut_chart(data['Genre'], palette="muted")
plt.title("Genres Distribution")
plt.axis("equal");

# %%
#Step-3: Plot the Distribution plots for the features
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Year'])
plt.subplot(1,2,2)
sns.distplot(df['NA_Sales'])

plt.show()

# %%
numeric_column = ['Year', 'NA_Sales',
       'EU_Sales', 'JP_Sales', 'Other_Sales','Global_Sales']

# %%
# check outlier using boxplot
df.boxplot(column=numeric_column,fontsize=10,rot=0,grid=False,figsize=(15,15),vert=False)
# Out:
# <AxesSubplot:>

# %%
# simple data checking - get columns name
print(df.columns)
# Out:
# Index(['Rank', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
target_array = df[['Global_Sales']]
X_train, X_test, y_train, y_test = train_test_split(
    df_normalized,
    target_array,
    train_size=0.8,
    random_state=0
)
# check the shape data
print('Shape Data X Train:')
print(X_train.shape)
print('\nShape Data X Test:')
print(X_test.shape)
print('\nShape Data y Train:')
print(y_train.shape)
print('\nShape Data y Test:')
print(y_test.shape)
# Out:
# Shape Data X Train:
# (13278, 10)
#
# Shape Data X Test:
# (3320, 10)
#
# Shape Data y Train:
# (13278, 1)
#
# Shape Data y Test:
# (3320, 1)

# %%
from sklearn import linear_model
regression_model = linear_model.LinearRegression()

# %%
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# Assuming X_train, y_train, X_test, and final_feature_array are your input data

# Step 1: Handle missing values
# Replace missing values with appropriate strategy (e.g., mean, median, etc.)
X_train = np.nan_to_num(X_train, nan=np.nanmean(X_train))
X_test = np.nan_to_num(X_test, nan=np.nanmean(X_train))
final_feature_array = np.nan_to_num(df_normalized, nan=np.nanmean(X_train))

# Step 2: Handle infinite values
# Replace infinite values with appropriate values
X_train[np.isinf(X_train)] = np.finfo(X_train.dtype).max
X_test[np.isinf(X_test)] = np.finfo(X_train.dtype).max
final_feature_array[np.isinf(final_feature_array)] = np.finfo(X_train.dtype).max

# Step 3: Scale your features
# Apply feature scaling using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
final_feature_array = scaler.transform(final_feature_array)

# Step 4: Perform Ridge regression (L2 regularization)
alpha = 0.5  # Regularization strength (you can adjust this value)
ridge_model = Ridge(alpha=alpha)
ridge_model.fit(X_train, y_train)

# Make predictions
y_train_pred = ridge_model.predict(X_train)
y_test_pred = ridge_model.predict(X_test)
target_array_pred = ridge_model.predict(final_feature_array)

# %%
print('Real Data')
print(y_train[:20])
print('\n Predicted Data')
print(y_train_pred[:20])
# Out:
# Real Data
#        Global_Sales
# 11199          0.09
# 11648          0.08
# 14120          0.03
# 14933          0.02
# 12119          0.07
# 9003           0.14
# 6667           0.25
# 8405           0.17
# 2856           0.71
# 6907           0.24
# 7562           0.20
# 13434          0.05
# 11664          0.08
# 13625          0.04
# 1961           1.06
# 10222          0.11
# 14318          0.03
# 11153          0.09
# 8706           0.16
# 7433           0.21
#
#  Predicted Data
# [[0.08452677]
#  [0.0802645 ]
#  [0.03053127]
#  [0.02042604]
#  [0.06452545]
#  [0.14594453]
#  [0.25015593]
#  [0.17024835]
#  [0.71580427]
#  [0.24002732]
#  [0.19430035]
#  [0.05038322]
#  [0.0746012 ]
#  [0.04048778]
#  [1.05985988]
#  [0.11043617]
#  [0.03044972]
#  [0.09032227]
#  [0.15999846]
#  [0.21022738]]
